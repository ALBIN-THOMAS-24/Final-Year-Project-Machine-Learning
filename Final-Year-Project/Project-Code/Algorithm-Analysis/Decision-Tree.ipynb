# %% [markdown]
# # DECISION TREE

# %%
#Criteria
#1. Gini Index
#2. Entropy

# %% [markdown]
# **1. Importing Libraries**

# %%
import pandas as pd #Reading CSV File
import matplotlib as plt #Plot

#Data Preprocessing and Split the dataset into training and  testing set
from sklearn import preprocessing
from sklearn.model_selection import train_test_split


from sklearn.tree import DecisionTreeClassifier #Decision Tree


#Model Evaluation
import sklearn.metrics as metrics #Finding the accuracy of the model
from sklearn.metrics import classification_report,confusion_matrix #classification Report  and Confusion matrix

# %%
data = pd.read_csv("C:\\machine\\science-dataset.csv")
data.head(5) #DISPLAY TOP 5 ROWS
data
# Out:
#               IQ   PHYSICS  CHEMISTRY     MATHS   BIOLOGY  COMPUTER  LANGUAGE  \
# 0      -1.008651 -0.646053   1.483130 -0.491651 -0.420337  0.029624 -0.099065
# 1      -0.516545  3.135103  -1.042419 -1.371282  0.088652 -0.926914  1.186076
# 2       1.330520 -0.449276  -0.746021 -0.224562 -0.511844 -0.068503 -0.488076
# 3      -1.443553 -0.209296   0.475726 -0.255531  1.069152  0.152201 -1.291762
# 4       0.893850  0.374306   0.951791 -0.698985 -0.415257 -1.542616 -0.750294
# ...          ...       ...        ...       ...       ...       ...       ...
# 449995 -0.649384 -0.529596  -0.160337 -0.059492 -0.336064 -0.138906  0.297975
# 449996  1.323730  0.968985   1.498581 -0.587843  0.164721  1.223582 -1.574406
# 449997  0.030982  0.162884   0.799824  0.263206  0.613781 -0.218501  2.371391
# 449998  0.081134  0.399378   1.779173  0.256633  1.810643  1.623142  0.121516
# 449999 -1.759659  0.075324  -0.295694 -0.630725 -0.549202  0.200475 -1.603906
#
# ...

# %% [markdown]
# **2: Data Scaling and  Splitting**

# %%
#Data Scaling
X=data.drop(['CAREER'], axis = 1).values 
print("Scaled Data")
Standardisation = preprocessing.StandardScaler()#Standard Scaling
AFTER_SCALE= Standardisation.fit_transform(X) 
print(AFTER_SCALE)
print("\n")
X=AFTER_SCALE #Input Features
y = data['CAREER'] #Output Label
X=X[:50000]
y=y[:50000]




#Split the Data into training and testing set 
#80% data used for training and 20% data used for testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=0)
print("\n")
# Out:
# Scaled Data
# [[-1.01022323e+00 -6.45237302e-01  1.11300196e+00 ...  1.11706852e+00
#   -1.48495673e+00  6.17447285e-01]
#  [-5.17847197e-01  3.13543283e+00 -7.81765445e-01 ...  4.55098220e-01
#   -1.44202551e+00 -3.53916847e-01]
#  [ 1.33023274e+00 -4.48486098e-01 -5.59395959e-01 ... -2.19445277e-01
#    1.04505909e+00  1.42245191e+00]
#  ...
#  [ 2.99809168e-02  1.63595665e-01  6.00358124e-01 ...  6.96918721e-01
#   -1.15012005e+00  5.91665972e-01]
#  [ 8.01600072e-02  4.00059078e-01  1.33510530e+00 ... -6.37413053e-01
#    1.97773150e-03  5.83187598e-01]
#  [-1.76164381e+00  7.60466658e-02 -2.21542851e-01 ... -1.21197124e+00
#   -1.27333845e+00 -2.70203358e-01]]

# %% [markdown]
# # Gini Index

# %%
Decision_tree= DecisionTreeClassifier(criterion = 'gini') #Decision Tree
Decision_tree.fit(X_train, y_train)#Training
y_t=Decision_tree.predict(X_train)#predict train
y_pred = Decision_tree.predict(X_test) #Predict test
#Model Evaluation

print("Decision_tree train Accuracy => "+str(metrics.accuracy_score(y_train, y_t)*100)+str(" %"))#Accuracy
print("Decision_tree test Accuracy => "+str(metrics.accuracy_score(y_test, y_pred)*100)+str(" %"))#Accuracy

print("\n")
print("Confusion Matrix")
from sklearn.metrics import plot_confusion_matrix
disp = plot_confusion_matrix(Decision_tree, X_test, y_test) #Confusion Matrix
print(disp.confusion_matrix)
print("\n")
print("Classification Report")
print(classification_report(y_test,y_pred)) #Classification Report
# Out:
# Decision_tree train Accuracy => 100.0 %
# Decision_tree test Accuracy => 86.83 %
#
#
# Confusion Matrix
# [[2888  177  234]
#  [ 186 2985  245]
#  [ 234  241 2810]]
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.87      3299
#            1       0.88      0.87      0.88      3416
#            2       0.85      0.86      0.85      3285
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000

# %% [markdown]
# # Entropy

# %%
Decision_tree= DecisionTreeClassifier(criterion = 'entropy') #Decision Tree
Decision_tree.fit(X_train, y_train)#Training
y_t=Decision_tree.predict(X_train)#predict train
y_pred = Decision_tree.predict(X_test) #Predict test
#Model Evaluation

print("Decision_tree train Accuracy => "+str(metrics.accuracy_score(y_train, y_t)*100)+str(" %"))#Accuracy
print("Decision_tree test Accuracy => "+str(metrics.accuracy_score(y_test, y_pred)*100)+str(" %"))#Accuracy
print("\n")
print("Confusion Matrix")
from sklearn.metrics import plot_confusion_matrix
disp = plot_confusion_matrix(Decision_tree, X_test, y_test) #Confusion Matrix
print(disp.confusion_matrix)
print("\n")
print("Classification Report")
print(classification_report(y_test,y_pred)) #Classification Report
# Out:
# Decision_tree train Accuracy => 100.0 %
# Decision_tree test Accuracy => 86.89 %
#
#
# Confusion Matrix
# [[2895  193  211]
#  [ 182 2981  253]
#  [ 232  240 2813]]
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.88      3299
#            1       0.87      0.87      0.87      3416
#            2       0.86      0.86      0.86      3285
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000

# %% [markdown]
# # Commerce Dataset: 2 lakh data

# %%
data = pd.read_csv("C:\\machine\\commerce-dataset.csv")
data.head(5) #DISPLAY TOP 5 ROWS
data
# Out:
#               IQ  ACCOUNTANCY  BUSINESS STUDIES  ECONOMICS   ENGLISH  \
# 0       0.245119    -0.851747          0.588909   1.529945 -1.611591
# 1      -1.168922     0.031583          0.432711  -0.268296  0.970550
# 2      -0.041283     0.280792         -0.831895   1.397449  0.550499
# 3       0.360363    -0.999669          1.142266   0.133847  2.033926
# 4      -0.789811    -0.543417          0.328899   0.428675 -0.024837
# ...          ...          ...               ...        ...       ...
# 199995  0.410492     0.376586         -0.322191  -0.517740  0.588816
# 199996  1.548518    -1.090067          0.946584   0.098185  0.261898
# 199997 -0.293363     0.546179          1.454924  -0.446401 -0.949430
# 199998 -0.190749     0.174764          1.236877   0.540462  0.476262
# 199999 -0.351894     1.514217          0.280358  -0.617223 -0.569607
#
#         INFORMATION PRACTICES/MATHEMATICS  LEGAL STUDIES  OPENNESS  \
# 0                                0.788213      -1.552692  1.256968
# ...

# %%
#Data Scaling
X=data.drop(['CAREER'], axis = 1).values 
print("Scaled Data")
Standardisation = preprocessing.StandardScaler()#Standard Scaling
AFTER_SCALE= Standardisation.fit_transform(X) 
print(AFTER_SCALE)
print("\n")
X=AFTER_SCALE #Input Features
y = data['CAREER'] #Output Label
X=X[:50000]
y=y[:50000]





#Split the Data into training and testing set 
#80% data used for training and 20% data used for testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=0)
print("\n")
# Out:
# Scaled Data
# [[ 0.24568831 -0.84811566  0.59238466 ... -0.74003098  0.84156985
#   -1.97034714]
#  [-1.17232281  0.03364377  0.43613436 ... -1.01396808  0.88089232
#   -0.78525331]
#  [-0.04151851  0.28240994 -0.82889404 ...  0.56637192  0.84322125
#    0.15886304]
#  ...
#  [-0.29430557  0.54732491  1.45868918 ... -0.18934601 -0.09286142
#   -1.29003794]
#  [-0.19140339  0.17657008  1.24056875 ...  0.47350013 -0.43188206
#   -1.85895264]
#  [-0.35300072  1.51364061  0.28373126 ... -0.75587931  1.64742374
#   -1.16689615]]

# %% [markdown]
# # Gini Index

# %%
Decision_tree= DecisionTreeClassifier(criterion = 'gini') #Decision Tree
Decision_tree.fit(X_train, y_train)#Training

y_t=Decision_tree.predict(X_train)#predict train
y_pred = Decision_tree.predict(X_test) #Predict test
#Model Evaluation

print("Decision_tree train Accuracy => "+str(metrics.accuracy_score(y_train, y_t)*100)+str(" %"))#Accuracy
print("Decision_tree test Accuracy => "+str(metrics.accuracy_score(y_test, y_pred)*100)+str(" %"))#Accuracy
print("\n")
print("Confusion Matrix")
from sklearn.metrics import plot_confusion_matrix
disp = plot_confusion_matrix(Decision_tree, X_test, y_test) #Confusion Matrix
print(disp.confusion_matrix)
print("\n")
print("Classification Report")
print(classification_report(y_test,y_pred)) #Classification Report
# Out:
# Decision_tree train Accuracy => 100.0 %
# Decision_tree test Accuracy => 94.42 %
#
#
# Confusion Matrix
# [[3174   43  163]
#  [  51 3192   72]
#  [ 135   94 3076]]
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      3380
#            1       0.96      0.96      0.96      3315
#            2       0.93      0.93      0.93      3305
#
#     accuracy                           0.94     10000
#    macro avg       0.94      0.94      0.94     10000
# weighted avg       0.94      0.94      0.94     10000

# %% [markdown]
# # Entropy

# %%
Decision_tree= DecisionTreeClassifier(criterion = 'entropy') #Decision Tree
Decision_tree.fit(X_train, y_train)#Training
y_t=Decision_tree.predict(X_train)#predict train
y_pred = Decision_tree.predict(X_test) #Predict test
#Model Evaluation

print("Decision_tree train Accuracy => "+str(metrics.accuracy_score(y_train, y_t)*100)+str(" %"))#Accuracy
print("Decision_tree test Accuracy => "+str(metrics.accuracy_score(y_test, y_pred)*100)+str(" %"))#Accuracy
print("\n")
print("Confusion Matrix")
from sklearn.metrics import plot_confusion_matrix
disp = plot_confusion_matrix(Decision_tree, X_test, y_test) #Confusion Matrix
print(disp.confusion_matrix)
print("\n")
print("Classification Report")
print(classification_report(y_test,y_pred)) #Classification Report
# Out:
# Decision_tree train Accuracy => 100.0 %
# Decision_tree test Accuracy => 94.54 %
#
#
# Confusion Matrix
# [[3175   50  155]
#  [  49 3198   68]
#  [ 138   86 3081]]
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      3380
#            1       0.96      0.96      0.96      3315
#            2       0.93      0.93      0.93      3305
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000

# %% [markdown]
# # Humanities Dataset: 1.5 lakh data

# %%
data = pd.read_csv("C:\\machine\\humanities-dataset.csv")
data.head(5) #DISPLAY TOP 5 ROWS
data
# Out:
#               IQ   HISTORY  ECONOMICS  SOCIOLOGY  GEOGRAPHY  \
# 0       1.651165  1.300911  -1.353804  -0.798610   0.329610
# 1       0.791091  2.197572   0.245021  -0.802328   0.235874
# 2       1.377100  1.698003   0.855287   1.521133  -0.384961
# 3      -1.635528  1.250182  -0.270923   0.094553   0.436016
# 4      -0.545640  0.361642   0.538216   0.678140  -0.772476
# ...          ...       ...        ...        ...        ...
# 149995 -0.171581  0.564884   1.498442   1.148015  -0.546012
# 149996  0.802646  0.511517   0.313318   0.178585  -1.216828
# 149997  1.233953 -1.600841  -1.508586  -1.077189   0.658685
# 149998  1.749874  1.090436  -0.065270  -0.350631   1.723826
# 149999  0.083393 -0.914092   0.914970   0.339343  -1.787504
#
#         POLITICAL SCIENCE  LANGUAGE  OPENNESS  CONSCIENTIOUSNESS  \
# 0               -0.261548 -0.957768 -1.955050           0.513994
# 1                0.005891 -0.310359  0.267041          -0.002142
# ...

# %%
#Data Scaling
X=data.drop(['CAREER'], axis = 1).values 
print("Scaled Data")
Standardisation = preprocessing.StandardScaler()#Standard Scaling
AFTER_SCALE= Standardisation.fit_transform(X) 
print(AFTER_SCALE)
print("\n")
X=AFTER_SCALE #Input Features
y = data['CAREER'] #Output Label

X=X[:50000]
y=y[:50000]


#Split the Data into training and testing set 
#80% data used for training and 20% data used for testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=0)
print("\n")
# Out:
# Scaled Data
# [[ 0.24568831 -0.84811566  0.59238466 ... -0.74003098  0.84156985
#   -1.97034714]
#  [-1.17232281  0.03364377  0.43613436 ... -1.01396808  0.88089232
#   -0.78525331]
#  [-0.04151851  0.28240994 -0.82889404 ...  0.56637192  0.84322125
#    0.15886304]
#  ...
#  [-0.29430557  0.54732491  1.45868918 ... -0.18934601 -0.09286142
#   -1.29003794]
#  [-0.19140339  0.17657008  1.24056875 ...  0.47350013 -0.43188206
#   -1.85895264]
#  [-0.35300072  1.51364061  0.28373126 ... -0.75587931  1.64742374
#   -1.16689615]]

# %% [markdown]
# # Gini Index

# %%
Decision_tree= DecisionTreeClassifier(criterion = 'gini') #Decision Tree
Decision_tree.fit(X_train, y_train)#Training
y_t=Decision_tree.predict(X_train)#predict train
y_pred = Decision_tree.predict(X_test) #Predict test
#Model Evaluation

print("Decision_tree train Accuracy => "+str(metrics.accuracy_score(y_train, y_t)*100)+str(" %"))#Accuracy
print("Decision_tree test Accuracy => "+str(metrics.accuracy_score(y_test, y_pred)*100)+str(" %"))#Accuracy
print("\n")
print("Confusion Matrix")
from sklearn.metrics import plot_confusion_matrix
disp = plot_confusion_matrix(Decision_tree, X_test, y_test) #Confusion Matrix
print(disp.confusion_matrix)
print("\n")
print("Classification Report")
print(classification_report(y_test,y_pred)) #Classification Report
# Out:
# Decision_tree train Accuracy => 100.0 %
# Decision_tree test Accuracy => 94.63000000000001 %
#
#
# Confusion Matrix
# [[3190   42  148]
#  [  55 3186   74]
#  [ 133   85 3087]]
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      3380
#            1       0.96      0.96      0.96      3315
#            2       0.93      0.93      0.93      3305
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000

# %% [markdown]
# # Entropy

# %%
Decision_tree= DecisionTreeClassifier(criterion = 'entropy') #Decision Tree
Decision_tree.fit(X_train, y_train)#Training
y_t=Decision_tree.predict(X_train)#predict train
y_pred = Decision_tree.predict(X_test) #Predict test
#Model Evaluation

print("Decision_tree train Accuracy => "+str(metrics.accuracy_score(y_train, y_t)*100)+str(" %"))#Accuracy
print("Decision_tree test Accuracy => "+str(metrics.accuracy_score(y_test, y_pred)*100)+str(" %"))#Accuracy
print("\n")
print("Confusion Matrix")
from sklearn.metrics import plot_confusion_matrix
disp = plot_confusion_matrix(Decision_tree, X_test, y_test) #Confusion Matrix
print(disp.confusion_matrix)
print("\n")
print("Classification Report")
print(classification_report(y_test,y_pred)) #Classification Report
# Out:
# Decision_tree train Accuracy => 100.0 %
# Decision_tree test Accuracy => 94.73 %
#
#
# Confusion Matrix
# [[3172   49  159]
#  [  44 3212   59]
#  [ 129   87 3089]]
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94      3380
#            1       0.96      0.97      0.96      3315
#            2       0.93      0.93      0.93      3305
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000
