# %% [markdown]
# # KNN

# %% [markdown]
# **1. Science Dataset : 50000 lakh data**

# %%
import pandas as pd
import numpy as np
data = pd.read_csv("C:\\machine\\science-dataset.csv")
data.head(10) #DISPLAY TOP 10 ROWS


#Data Scaling
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
X=data.drop(['CAREER'], axis = 1).values 
X=X[:50000]
print("Scaled Data")
Standardisation = preprocessing.StandardScaler()#Standard Scaling
AFTER_SCALE= Standardisation.fit_transform(X) 
print(AFTER_SCALE)
print("\n")
X=AFTER_SCALE #Input Features
y = data['CAREER'] #Output Label
y=y[:50000]
print(X.shape)
print(y.shape)

#Split the Data into training and testing set 
#80% data used for training and 20% data used for testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=0)
print("\n")




print("KNN")
from sklearn.neighbors import KNeighborsClassifier
#Model Evaluation
import sklearn.metrics as metrics #Finding the accuracy of the model
from sklearn.metrics import classification_report,confusion_matrix #classification Report  and Confusion matrix
import matplotlib as plt
knn = KNeighborsClassifier(n_neighbors = 7)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test) #Predict

#Model Evaluation
print("KNN_Accuracy => "+str(metrics.accuracy_score(y_test, y_pred)*100)+str(" %"))#Accuracy
print("\n")
print("Confusion Matrix")
from sklearn.metrics import plot_confusion_matrix
disp = plot_confusion_matrix(knn, X_test, y_test) #Confusion Matrix
print(disp.confusion_matrix)
print("\n")
print("Classification Report")
print(classification_report(y_test,y_pred)) #Classification Report
print("\n\n")
# Out:
# Scaled Data
# [[-1.0111445  -0.64193494  1.11900135 ...  1.12156888 -1.47871265
#    0.62892874]
#  [-0.51759924  3.13707614 -0.78996567 ...  0.45613134 -1.43579312
#   -0.34523398]
#  [ 1.33486924 -0.44527008 -0.56592972 ... -0.22194525  1.05061466
#    1.43625265]
#  ...
#  [ 0.32801482 -0.07488618  1.06166717 ... -1.11379149 -0.98152571
#    0.12605541]
#  [ 0.51335459 -0.61920121 -1.87714355 ... -0.11499922  0.40177631
#    0.78182675]
#  [ 0.45665749 -0.56621444  1.57607873 ... -0.75533958  0.62784451
#   -0.91261124]]
#
#
# (50000, 22)
# (50000,)
#
#
# KNN
# KNN_Accuracy => 76.57000000000001 %
#
#
# Confusion Matrix
# [[2486  393  420]
#  [ 391 2696  329]
#  [ 358  452 2475]]
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76      3299
#            1       0.76      0.79      0.78      3416
#            2       0.77      0.75      0.76      3285
#
#     accuracy                           0.77     10000
#    macro avg       0.77      0.77      0.77     10000
# weighted avg       0.77      0.77      0.77     10000

# %% [markdown]
# **2. Commerce Dataset: 50000 data**

# %%
import pandas as pd
import numpy as np
data = pd.read_csv("C:\\machine\\commerce-dataset.csv")
data.head(10) #DISPLAY TOP 10 ROWS


#Data Scaling
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
X=data.drop(['CAREER'], axis = 1).values 
print("Scaled Data")
Standardisation = preprocessing.StandardScaler()#Standard Scaling
AFTER_SCALE= Standardisation.fit_transform(X) 
print(AFTER_SCALE)
print("\n")
X=AFTER_SCALE #Input Features
X=X[:50000]
y = data['CAREER'] #Output Label
y=y[:50000]
print(X.shape)
print(y.shape)

#Split the Data into training and testing set 
#80% data used for training and 20% data used for testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=0)
print("\n")




print("KNN")
from sklearn.neighbors import KNeighborsClassifier
#Model Evaluation
import sklearn.metrics as metrics #Finding the accuracy of the model
from sklearn.metrics import classification_report,confusion_matrix #classification Report  and Confusion matrix
import matplotlib as plt
knn = KNeighborsClassifier(n_neighbors = 7)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test) #Predict

#Model Evaluation
print("KNN_Accuracy => "+str(metrics.accuracy_score(y_test, y_pred)*100)+str(" %"))#Accuracy
print("\n")
print("Confusion Matrix")
from sklearn.metrics import plot_confusion_matrix
disp = plot_confusion_matrix(knn, X_test, y_test) #Confusion Matrix
print(disp.confusion_matrix)
print("\n")
print("Classification Report")
print(classification_report(y_test,y_pred)) #Classification Report
print("\n\n")
# Out:
# Scaled Data
# [[ 0.24568831 -0.84811566  0.59238466 ... -0.74003098  0.84156985
#   -1.97034714]
#  [-1.17232281  0.03364377  0.43613436 ... -1.01396808  0.88089232
#   -0.78525331]
#  [-0.04151851  0.28240994 -0.82889404 ...  0.56637192  0.84322125
#    0.15886304]
#  ...
#  [-0.29430557  0.54732491  1.45868918 ... -0.18934601 -0.09286142
#   -1.29003794]
#  [-0.19140339  0.17657008  1.24056875 ...  0.47350013 -0.43188206
#   -1.85895264]
#  [-0.35300072  1.51364061  0.28373126 ... -0.75587931  1.64742374
#   -1.16689615]]
#
#
# (50000, 22)
# (50000,)
#
#
# KNN
# KNN_Accuracy => 81.17999999999999 %
#
#
# Confusion Matrix
# [[2624  122  634]
#  [  54 3054  207]
#  [ 544  321 2440]]
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.81      0.78      0.79      3380
#            1       0.87      0.92      0.90      3315
#            2       0.74      0.74      0.74      3305
#
#     accuracy                           0.81     10000
#    macro avg       0.81      0.81      0.81     10000
# weighted avg       0.81      0.81      0.81     10000

# %% [markdown]
# **3. Humanities Dataset : 50000 data**

# %%
import pandas as pd
import numpy as np
data = pd.read_csv("C:\\machine\\humanities-dataset.csv")
data.head(10) #DISPLAY TOP 10 ROWS


#Data Scaling
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
X=data.drop(['CAREER'], axis = 1).values 
print("Scaled Data")
Standardisation = preprocessing.StandardScaler()#Standard Scaling
AFTER_SCALE= Standardisation.fit_transform(X) 
print(AFTER_SCALE)
print("\n")
X=AFTER_SCALE #Input Features
X=X[:50000]
y = data['CAREER'] #Output Label
y=y[:50000]

print(X.shape)
print(y.shape)

#Split the Data into training and testing set 
#80% data used for training and 20% data used for testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=0)
print("\n")




print("KNN")
from sklearn.neighbors import KNeighborsClassifier
#Model Evaluation
import sklearn.metrics as metrics #Finding the accuracy of the model
from sklearn.metrics import classification_report,confusion_matrix #classification Report  and Confusion matrix
import matplotlib as plt
knn = KNeighborsClassifier(n_neighbors = 7)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test) #Predict

#Model Evaluation
print("KNN_Accuracy => "+str(metrics.accuracy_score(y_test, y_pred)*100)+str(" %"))#Accuracy
print("\n")
print("Confusion Matrix")
from sklearn.metrics import plot_confusion_matrix
disp = plot_confusion_matrix(knn, X_test, y_test) #Confusion Matrix
print(disp.confusion_matrix)
print("\n")
print("Classification Report")
print(classification_report(y_test,y_pred)) #Classification Report
print("\n\n")
# Out:
# Scaled Data
# [[ 1.65387287  1.29905166 -1.35037826 ... -1.53645037 -0.59739747
#    1.43158727]
#  [ 0.79354715  2.19748708  0.24791042 ... -1.505026   -0.07371361
#    1.25453011]
#  [ 1.37972835  1.69692931  0.85797214 ... -0.22954282  0.57205402
#    1.10842098]
#  ...
#  [ 1.23653922 -1.60844464 -1.50510814 ... -0.68939418  0.00466291
#   -1.06779219]
#  [ 1.75261127  1.08815958 -0.06227623 ...  0.86284206 -0.17064843
#    1.33240845]
#  [ 0.08564096 -0.92033662  0.91763489 ...  0.62457878 -0.495897
#    0.29817691]]
#
#
# (50000, 22)
# (50000,)
#
#
# KNN
# KNN_Accuracy => 78.0 %
#
#
# Confusion Matrix
# [[2664  239  403]
#  [ 284 2660  367]
#  [ 323  584 2476]]
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81      3306
#            1       0.76      0.80      0.78      3311
#            2       0.76      0.73      0.75      3383
#
#     accuracy                           0.78     10000
#    macro avg       0.78      0.78      0.78     10000
# weighted avg       0.78      0.78      0.78     10000
