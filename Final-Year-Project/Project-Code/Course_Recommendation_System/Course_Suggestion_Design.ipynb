# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

data=pd.read_csv('C:\\course_dataset\\udemy_design.csv')
data
# Out:
#       index                                              Title  \
# 0         0  The Ultimate Drawing Course - Beginner to Adva...
# 1         1  Character Art School: Complete Character Drawi...
# 2         2  Complete Blender Creator: Learn 3D Modelling f...
# 3         3                         Design Thinking in 3 Steps
# 4         4                    Illustrator CC 2020 MasterClass
# ...     ...                                                ...
# 9957   9957               Aprendé After Effects CC 2018 rápido
# 9958   9958  Sketchup - V-ray - Tworzenie modelu 3d i wizua...
# 9959   9959                     Aprende GIMP dibujando Kawaiis
# 9960   9960    Creación de animaciones cortas en After Effects
# 9961   9961                             El arco de la historia
#
#                                                 Summary  Enrollment  Stars  \
# 0     Learn the #1 most important building block of ...      403865    4.5
# 1     Learn How to Draw People and Character Designs...      228471    4.5
# 2     Use Blender to Create Beautiful 3D models for ...      203790    4.6
# 3     Understand your audience, envision a creative ...       63479    4.4
# 4     Master Adobe Illustrator CC with this in-depth...      117513    4.6
# ...                                                 ...         ...    ...
# 9957                              Aprendé en 80 minutos           7    4.3
# 9958  Chcesz nauczyć się tworzyć realistyczne modele...          40    4.2
# 9959  Aprende a manejar la mejor alternativa a Photo...          12    4.8
# 9960  Hacer realidad tu sueño de ver a tus personaje...          34    4.3
# 9961  Mantén interesado al espectador en toda la lec...           5    3.9
#
#       Rating                                               Link
# 0      98984  https://www.udemy.com/course/the-ultimate-draw...
# 1      51220  https://www.udemy.com/course/character-art-sch...
# 2      39959      https://www.udemy.com/course/blendertutorial/
# 3      28014  https://www.udemy.com/course/designit-design-t...
# 4      25858  https://www.udemy.com/course/illustrator-cc-ma...
# ...      ...                                                ...
# 9957       3  https://www.udemy.com/course/aftereffectscc201...
# 9958       3  https://www.udemy.com/course/sketchup-v-ray-tw...
# 9959       3  https://www.udemy.com/course/aprende-gimp-dibu...
# 9960       3  https://www.udemy.com/course/animaciones-corta...
# 9961       3  https://www.udemy.com/course/el-arco-de-la-his...
#
# [9962 rows x 7 columns]

# %%
user_input=input()
count=0
import re

print('\n')
print("Your Recommended Course")
print('\n')
for i in range(0,9961):
    k=str(data['Title'][i])
    l=str(data['Summary'][i])
    new_data=k+' '+l
   
    data_s=new_data
    pattern = r'[0-9]'
    data_s = re.sub(pattern, '', data_s)
   
    text=[user_input,data_s]
    cv=CountVectorizer()
    count_matrix=cv.fit_transform(text)
    sim_score=cosine_similarity(count_matrix)
    if(sim_score[0][1]>0.3 and count<5):
        count=count+1
        print('Course => ',data['Title'][i])
        print('Recommending_Score => '+str(sim_score[0][1]*100))
        print('Course rating => ',data['Stars'][i])
        print('\n')
# Out:
# CAD
#
#
# Your Recommended Course
#
#
# Course =>  Master Solidworks 2018 - 3D CAD using real-world examples
# Recommending_Score => 34.81553119113957
# Course rating =>  4.6
#
#
# Course =>  Master Solidworks 2015 - 3D CAD using real-world examples
# Recommending_Score => 35.92106040535498
# Course rating =>  4.4
#
#
# Course =>  Learning Autodesk AutoCAD 2016
# Recommending_Score => 31.622776601683793
# Course rating =>  4.6
#
#
# Course =>  Master Solidworks 2019 - 3D CAD using real-world examples
# Recommending_Score => 34.81553119113957
# Course rating =>  4.6
#
#
# Course =>  CAD for Woodworkers: makes it easy to draw woodworking plans
# Recommending_Score => 34.81553119113957
# Course rating =>  4.3
