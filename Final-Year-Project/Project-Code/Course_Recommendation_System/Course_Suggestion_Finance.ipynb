# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

data=pd.read_csv('C:\\course_dataset\\udemy_finance.csv')
data
# Out:
#       index                                              Title  \
# 0         0         The Complete Financial Analyst Course 2020
# 1         1  Beginner to Pro in Excel: Financial Modeling a...
# 2         2       The Complete Foundation Stock Trading Course
# 3         3  The Complete Financial Analyst Training & Inve...
# 4         4  Investing In Stocks The Complete Course! (11 H...
# ...     ...                                                ...
# 5882   5882  Finanças Pessoais - Faça o Controle Dos Seus R...
# 5883   5883                             מסחר אוטומטי בשוק ההון
# 5884   5884  ZOHO Books Usuario by SAGITAZ | ZOHO Premium P...
# 5885   5885          Acabou a Previdência e agora? - Volume 03
# 5886   5886                                Poderoso Investidor
#
#                                                 Summary  Enrollment  Stars  \
# 0     Excel, Accounting, Financial Statement Analysi...      249123    4.5
# 1     Financial Modeling in Excel that would allow y...      128940    4.6
# 2     Learn To Trade The Stock Market by A Trading F...       79089    4.5
# 3     Succeed as a Financial Analyst &Investor by Aw...      183645    4.5
# 4     Master Investing in the Stock Market with Stoc...      111937    4.4
# ...                                                 ...         ...    ...
# 5882  Descubra os 6 métodos eficazes para controlar ...          30    0.0
# 5883                                      אלגו טריידינג          22    0.0
# 5884  Tareas diarias del departamento de finanzas en...         214    0.0
# 5885                                     Renda Variável          18    5.0
# 5886              APRENDA COMO ESCOLHER UM INVESTIMENTO          72    0.0
#
#       Rating                                               Link
# 0      47466  https://www.udemy.com/course/the-complete-fina...
# 1      29128  https://www.udemy.com/course/beginner-to-pro-i...
# 2      22239    https://www.udemy.com/course/foundation-course/
# 3      21818  https://www.udemy.com/course/the-complete-fina...
# 4      20993  https://www.udemy.com/course/investing-in-stocks/
# ...      ...                                                ...
# 5882       0  https://www.udemy.com/course/financas-pessoais...
# 5883       0             https://www.udemy.com/course/btqhvihn/
# 5884       0  https://www.udemy.com/course/zoho-books-usuari...
# 5885       1  https://www.udemy.com/course/acabou-a-previden...
# 5886       0  https://www.udemy.com/course/poderoso-investidor/
#
# [5887 rows x 7 columns]

# %%
user_input=input()
count=0
import re

print('\n')
print("Your Recommended Course")
print('\n')
for i in range(0,5886):
    k=str(data['Title'][i])
    l=str(data['Summary'][i])
    new_data=k+' '+l
   
    data_s=new_data
    pattern = r'[0-9]'
    data_s = re.sub(pattern, '', data_s)
   
    text=[user_input,data_s]
    cv=CountVectorizer()
    count_matrix=cv.fit_transform(text)
    sim_score=cosine_similarity(count_matrix)
    if(sim_score[0][1]>0.3 and count<5):
        count=count+1
        print('Course => ',data['Title'][i])
        print('Recommending_Score => '+str(sim_score[0][1]*100))
        print('Course rating => ',data['Stars'][i])
        print('\n')
# Out:
# finance
#
#
# Your Recommended Course
#
#
# Course =>  Introduction to Finance, Accounting, Modeling and Valuation
# Recommending_Score => 38.490017945975055
# Course rating =>  4.5
#
#
# Course =>  Finance for Non-Finance: Learn Quick and Easy
# Recommending_Score => 41.70288281141495
# Course rating =>  4.4
#
#
# Course =>  The Core Four of Personal Finance including Recession Basics
# Recommending_Score => 32.025630761017425
# Course rating =>  4.5
#
#
# Course =>  Personal Finance Masterclass - Easy Guide to Better Finances
# Recommending_Score => 34.29971702850176
# Course rating =>  4.3
#
#
# Course =>  Finance for the Real World - Corporate Finance 101
# Recommending_Score => 55.708601453115556
# Course rating =>  4.2
