# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

data=pd.read_csv('C:\\course_dataset\\udemy_marketing.csv')
data
# Out:
#       index                                              Title  \
# 0         0  The Complete Digital Marketing Course - 12 Cou...
# 1         1  Ultimate Google Ads Training 2020: Profit with...
# 2         2  Instagram Marketing 2020: Complete Guide To In...
# 3         3  Facebook Ads & Facebook Marketing MASTERY 2020...
# 4         4    Digital Marketing Masterclass - 23 Courses in 1
# ...     ...                                                ...
# 8783   8783          הקסם שבשיווק - הקורס המקיף ליסודות השיווק
# 8784   8784   La méthode efficace pour planifier sur Instagram
# 8785   8785    Divulgando sua empresa no Facebook e Google Ads
# 8786   8786  Destaca de los demás canales como yo|Método qu...
# 8787   8787  Un Plan Paso A Paso Para Llevar Tu Negocio A I...
#
#                                                 Summary  Enrollment  Stars  \
# 0     Master Digital Marketing Strategy, Social Medi...      494107    4.4
# 1     Google Ads 2020: How our clients have transfor...      159200    4.7
# 2     Attract Hyper-Targeted Instagram Followers, Co...      128185    4.4
# 3     Facebook Marketing from beginner to advanced! ...      157240    4.4
# 4     Grow Your Business with Digital Marketing: Soc...      188603    4.4
# ...                                                 ...         ...    ...
# 8783  לא משנה אם יש לכם עסק דיגיטלי או פרונטלי, פה ת...           2    0.0
# 8784  Cette méthode permets de publier du contenu pe...           2    0.0
# 8785  Quem não é visto não é lembrado divulgue sua e...           1    0.0
# 8786  Posiciona todos tus vídeos y obtén cientos de ...           3    0.0
# 8787  - Sin necesidad de experiencia previa ni inver...           4    0.0
#
#       Rating                                               Link
# 0     117014  https://www.udemy.com/course/learn-digital-mar...
# 1      39979  https://www.udemy.com/course/the-ultimate-goog...
# 2      24520  https://www.udemy.com/course/instagram-marketi...
# 3      24351  https://www.udemy.com/course/facebook-ads-face...
# 4      14107  https://www.udemy.com/course/digital-marketing...
# ...      ...                                                ...
# 8783       0  https://www.udemy.com/course/themagicofmarketing/
# 8784       0  https://www.udemy.com/course/la-methode-effica...
# 8785       0  https://www.udemy.com/course/como-divulgar-sua...
# 8786       0  https://www.udemy.com/course/todo-para-iniciar...
# 8787       0  https://www.udemy.com/course/un-plan-para-llev...
#
# [8788 rows x 7 columns]

# %%
user_input=input()
count=0
import re

print('\n')
print("Your Recommended Course")
print('\n')
for i in range(0,8787):
    k=str(data['Title'][i])
    l=str(data['Summary'][i])
    new_data=k+' '+l
   
    data_s=new_data
    pattern = r'[0-9]'
    data_s = re.sub(pattern, '', data_s)
   
    text=[user_input,data_s]
    cv=CountVectorizer()
    count_matrix=cv.fit_transform(text)
    sim_score=cosine_similarity(count_matrix)
    if(sim_score[0][1]>0.3 and count<5):
        count=count+1
        print('Course => ',data['Title'][i])
        print('Recommending_Score => '+str(sim_score[0][1]*100))
        print('Course rating => ',data['Stars'][i])
        print('\n')
# Out:
# marketing
#
#
# Your Recommended Course
#
#
# Course =>  The Complete Digital Marketing Course - 12 Courses in 1
# Recommending_Score => 67.61234037828132
# Course rating =>  4.4
#
#
# Course =>  Digital Marketing Masterclass - 23 Courses in 1
# Recommending_Score => 68.59943405700352
# Course rating =>  4.4
#
#
# Course =>  Social Media Marketing MASTERY | Learn Ads on 10+ Platforms
# Recommending_Score => 37.13906763541037
# Course rating =>  4.4
#
#
# Course =>  Mega Digital Marketing Course A-Z: 12 Courses in 1 + Updates
# Recommending_Score => 52.22329678670935
# Course rating =>  4.4
#
#
# Course =>  Digital Marketing Certification: Master Digital Marketing
# Recommending_Score => 58.34599659915782
# Course rating =>  4.2
