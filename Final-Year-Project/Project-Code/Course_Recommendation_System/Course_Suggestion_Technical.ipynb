# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

data=pd.read_csv('C:\\course_dataset\\udemy_tech.csv')
data
# Out:
#       index                                              Title  \
# 0         0  2020 Complete Python Bootcamp: From Zero to He...
# 1         1                         The Web Developer Bootcamp
# 2         2  Machine Learning A-Z™: Hands-On Python & R In ...
# 3         3        Angular - The Complete Guide (2020 Edition)
# 4         4  Java Programming Masterclass for Software Deve...
# ...     ...                                                ...
# 9959   9959  MonoDevelop/Visual Studio Mac & Unity ; Pro Ti...
# 9960   9960                     Unity Game Tutorial: Tetris 3D
# 9961   9961      Spring 5.0 Project: Building a Travel Website
# 9962   9962  Guide to Powershell 6 and Automating Active Di...
# 9963   9963  The Complete Express.js Developer Course & Cre...
#
#                                                 Summary  Enrollment  Stars  \
# 0     Learn Python like a Professional! Start from t...     1100093    4.6
# 1     The only course you need to learn web developm...      596726    4.6
# 2     Learn to create Machine Learning Algorithms in...      692812    4.5
# 3     Master Angular 10 (formerly "Angular 2") and b...      422557    4.6
# 4     Learn Java In This Course And Become a Compute...      502572    4.6
# ...                                                 ...         ...    ...
# 9959  Lay down consistent code at the speed of thoug...          84    4.0
# 9960  Learn how to create a Tetris 3D in Unity Game ...          86    4.4
# 9961  Design and implement real-world web-based appl...          70    3.5
# 9962  Use PowerShell for Active Directory to elimina...         119    4.2
# 9963  Beginner at the beginning of the course and an...        2329    3.3
#
#       Rating                                               Link
# 0     318066  https://www.udemy.com/course/complete-python-b...
# 1     182997  https://www.udemy.com/course/the-web-developer...
# 2     132228      https://www.udemy.com/course/machinelearning/
# 3     129984  https://www.udemy.com/course/the-complete-guid...
# 4     123798  https://www.udemy.com/course/java-the-complete...
# ...      ...                                                ...
# 9959       9  https://www.udemy.com/course/monodevelop-with-...
# 9960       9  https://www.udemy.com/course/unity-game-tutori...
# 9961       9  https://www.udemy.com/course/spring-50-project...
# 9962       9  https://www.udemy.com/course/guide-to-powershe...
# 9963       9  https://www.udemy.com/course/the-complete-expr...
#
# [9964 rows x 7 columns]

# %%
user_input=input()
count=0
import re

print('\n')
print("Your Recommended Course")
print('\n')
for i in range(0,9963):
    k=str(data['Title'][i])
    l=str(data['Summary'][i])
    new_data=k+' '+l
   
    data_s=new_data
    pattern = r'[0-9]'
    data_s = re.sub(pattern, '', data_s)
   
    text=[user_input,data_s]
    cv=CountVectorizer()
    count_matrix=cv.fit_transform(text)
    sim_score=cosine_similarity(count_matrix)
    if(sim_score[0][1]>0.3 and count<5):
        count=count+1
        print('Course => ',data['Title'][i])
        print('Recommending_Score => '+str(sim_score[0][1]*100))
        print('Course rating => ',data['Stars'][i])
        
        print('\n')
# Out:
# I love Python
#
#
# Your Recommended Course
#
#
# Course =>  2020 Complete Python Bootcamp: From Zero to Hero in Python
# Recommending_Score => 32.34983196103152
# Course rating =>  4.6
#
#
# Course =>  Learn Python Programming Masterclass
# Recommending_Score => 55.21576303742327
# Course rating =>  4.5
#
#
# Course =>  The Python Mega Course: Build 10 Real World Applications
# Recommending_Score => 46.499055497527706
# Course rating =>  4.5
#
#
# Course =>  The Python Bible™ | Everything You Need to Program in Python
# Recommending_Score => 41.256849850351735
# Course rating =>  4.6
#
#
# Course =>  The Modern Python 3 Bootcamp
# Recommending_Score => 36.514837167011066
# Course rating =>  4.7
